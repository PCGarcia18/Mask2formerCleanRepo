# %%
test_images_names_list = [    
    "GF2_PMS1__L1A0001064454-MSS1",
    "GF2_PMS1__L1A0001118839-MSS1",
    "GF2_PMS1__L1A0001344822-MSS1",
    "GF2_PMS1__L1A0001348919-MSS1",
    "GF2_PMS1__L1A0001366278-MSS1",
    "GF2_PMS1__L1A0001366284-MSS1",
    "GF2_PMS1__L1A0001395956-MSS1",
    "GF2_PMS1__L1A0001432972-MSS1",
    "GF2_PMS1__L1A0001670888-MSS1",
    "GF2_PMS1__L1A0001680857-MSS1",
    "GF2_PMS1__L1A0001680858-MSS1",
    "GF2_PMS1__L1A0001757429-MSS1",
    "GF2_PMS1__L1A0001765574-MSS1",
    "GF2_PMS2__L1A0000607677-MSS2",
    "GF2_PMS2__L1A0000607681-MSS2",
    "GF2_PMS2__L1A0000718813-MSS2",
    "GF2_PMS2__L1A0001038935-MSS2",
    "GF2_PMS2__L1A0001038936-MSS2",
    "GF2_PMS2__L1A0001119060-MSS2",
    "GF2_PMS2__L1A0001367840-MSS2",
    "GF2_PMS2__L1A0001378491-MSS2",
    "GF2_PMS2__L1A0001378501-MSS2",
    "GF2_PMS2__L1A0001396036-MSS2",
    "GF2_PMS2__L1A0001396037-MSS2",
    "GF2_PMS2__L1A0001416129-MSS2",
    "GF2_PMS2__L1A0001471436-MSS2",
    "GF2_PMS2__L1A0001517494-MSS2",
    "GF2_PMS2__L1A0001591676-MSS2",
    "GF2_PMS2__L1A0001787564-MSS2",
    "GF2_PMS2__L1A0001821754-MSS2"
    ]


images_dir = "/home/pablo.canosa/wip/datasets/gaofen/Image__8bit_NirRGB/"

destiny_path_image = "/home/pablo.canosa/wip/datasets/gaofen/train_8bit/"
import os

for image_idx, image_filename in enumerate(os.listdir(images_dir)):
    #This is used to check if the test images are in train
    #delete the file of extension od image_filename
    image_filename_cmp = image_filename.split(".")[0]
    if image_filename_cmp not in test_images_names_list:
        print(f"{image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + images_dir + image_filename + " " + destiny_path_image)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
# Out:
# GF2_PMS1__L1A0001094941-MSS1.tif is 0
# GF2_PMS2__L1A0001537637-MSS2.tif is 1
# GF2_PMS2__L1A0001251800-MSS2.tif is 2
# GF2_PMS2__L1A0001799010-MSS2.tif is 3
# GF2_PMS2__L1A0001566654-MSS2.tif is 5
# GF2_PMS2__L1A0001787577-MSS2.tif is 6
# GF2_PMS1__L1A0001015646-MSS1.tif is 7
# GF2_PMS2__L1A0000564691-MSS2.tif is 8
# GF2_PMS2__L1A0001708232-MSS2.tif is 10
# GF2_PMS2__L1A0000958144-MSS2.tif is 11
# GF2_PMS1__L1A0001668483-MSS1.tif is 12
# GF2_PMS1__L1A0001112719-MSS1.tif is 15
# GF2_PMS1__L1A0001765572-MSS1.tif is 16
# GF2_PMS2__L1A0001396034-MSS2.tif is 18
# GF2_PMS1__L1A0000708367-MSS1.tif is 21
# GF2_PMS1__L1A0001169100-MSS1.tif is 23
# GF2_PMS2__L1A0001886305-MSS2.tif is 25
# GF2_PMS2__L1A0001746797-MSS2.tif is 26
# GF2_PMS1__L1A0000647768-MSS1.tif is 27
# GF2_PMS2__L1A0001389317-MSS2.tif is 28
# GF2_PMS2__L1A0001768200-MSS2.tif is 30
# GF2_PMS2__L1A0001574001-MSS2.tif is 31
# GF2_PMS2__L1A0001251799-MSS2.tif is 32
# GF2_PMS2__L1A0001668457-MSS2.tif is 33
# ...

# %%
test_masks_names= [    
    "GF2_PMS1__L1A0001064454-MSS1_24label",
    "GF2_PMS1__L1A0001118839-MSS1_24label",
    "GF2_PMS1__L1A0001344822-MSS1_24label",
    "GF2_PMS1__L1A0001348919-MSS1_24label",
    "GF2_PMS1__L1A0001366278-MSS1_24label",
    "GF2_PMS1__L1A0001366284-MSS1_24label",
    "GF2_PMS1__L1A0001395956-MSS1_24label",
    "GF2_PMS1__L1A0001432972-MSS1_24label",
    "GF2_PMS1__L1A0001670888-MSS1_24label",
    "GF2_PMS1__L1A0001680857-MSS1_24label",
    "GF2_PMS1__L1A0001680858-MSS1_24label",
    "GF2_PMS1__L1A0001757429-MSS1_24label",
    "GF2_PMS1__L1A0001765574-MSS1_24label",
    "GF2_PMS2__L1A0000607677-MSS2_24label",
    "GF2_PMS2__L1A0000607681-MSS2_24label",
    "GF2_PMS2__L1A0000718813-MSS2_24label",
    "GF2_PMS2__L1A0001038935-MSS2_24label",
    "GF2_PMS2__L1A0001038936-MSS2_24label",
    "GF2_PMS2__L1A0001119060-MSS2_24label",
    "GF2_PMS2__L1A0001367840-MSS2_24label",
    "GF2_PMS2__L1A0001378491-MSS2_24label",
    "GF2_PMS2__L1A0001378501-MSS2_24label",
    "GF2_PMS2__L1A0001396036-MSS2_24label",
    "GF2_PMS2__L1A0001396037-MSS2_24label",
    "GF2_PMS2__L1A0001416129-MSS2_24label",
    "GF2_PMS2__L1A0001471436-MSS2_24label",
    "GF2_PMS2__L1A0001517494-MSS2_24label",
    "GF2_PMS2__L1A0001591676-MSS2_24label",
    "GF2_PMS2__L1A0001787564-MSS2_24label",
    "GF2_PMS2__L1A0001821754-MSS2_24label"
    ]

# %%
colored_masks = "/home/pablo.canosa/wip/datasets/gaofen/Annotation__color/"


train_colored_masks_destiny = "/home/pablo.canosa/wip/datasets/gaofen/train_color_masks"
test_colored_masks_destiny = "/home/pablo.canosa/wip/datasets/gaofen/test_color_masks/"

for image_idx, image_filename in enumerate(os.listdir(colored_masks)):
    #This is used to check if the test images are in train
    #delete the file of extension od image_filename
    image_filename_cmp = image_filename.split(".")[0]
    if image_filename_cmp not in test_masks_names:
        print(f"TRAIN {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + colored_masks + image_filename + " " + train_colored_masks_destiny)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
    else:
        print(f"TEST {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + colored_masks + image_filename + " " + test_colored_masks_destiny)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
# Out:
# TRAIN GF2_PMS2__L1A0001092725-MSS2_24label.tif is 0
# TRAIN GF2_PMS2__L1A0001573999-MSS2_24label.tif is 1
# TRAIN GF2_PMS2__L1A0001746797-MSS2_24label.tif is 2
# TRAIN GF2_PMS1__L1A0000564539-MSS1_24label.tif is 3
# TRAIN GF2_PMS1__L1A0001104323-MSS1_24label.tif is 4
# TRAIN GF2_PMS2__L1A0000658637-MSS2_24label.tif is 5
# TRAIN GF2_PMS1__L1A0000647768-MSS1_24label.tif is 6
# TRAIN GF2_PMS1__L1A0001821711-MSS1_24label.tif is 7
# TRAIN GF2_PMS1__L1A0001015646-MSS1_24label.tif is 8
# TRAIN GF2_PMS1__L1A0001112719-MSS1_24label.tif is 9
# TRAIN GF2_PMS1__L1A0001765570-MSS1_24label.tif is 10
# TRAIN GF2_PMS1__L1A0001094941-MSS1_24label.tif is 11
# TRAIN GF2_PMS2__L1A0001799009-MSS2_24label.tif is 12
# TEST GF2_PMS2__L1A0001591676-MSS2_24label.tif is 13
# TRAIN GF2_PMS1__L1A0001910522-MSS1_24label.tif is 14
# TRAIN GF2_PMS2__L1A0001416140-MSS2_24label.tif is 15
# TRAIN GF2_PMS1__L1A0001734328-MSS1_24label.tif is 16
# TRAIN GF2_PMS2__L1A0001119057-MSS2_24label.tif is 17
# ...

# %%
grayscale_masks = "/home/pablo.canosa/wip/datasets/gaofen/Annotation__index/"

train_grayscale_masks_destiny = "/home/pablo.canosa/wip/datasets/gaofen/train_grayscale_masks"
test_grayscale_masks_destiny = "/home/pablo.canosa/wip/datasets/gaofen/test_grayscale_masks/"

for image_idx, image_filename in enumerate(os.listdir(grayscale_masks)):
    #This is used to check if the test images are in train
    #delete the file of extension od image_filename
    image_filename_cmp = image_filename.split(".")[0]
    if image_filename_cmp not in test_masks_names:
        print(f"TRAIN {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + grayscale_masks + image_filename + " " + train_grayscale_masks_destiny)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
    else:
        print(f"TEST {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + grayscale_masks + image_filename + " " + test_grayscale_masks_destiny)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
# Out:
# TRAIN GF2_PMS2__L1A0000788763-MSS2_24label.png is 0
# TRAIN GF2_PMS2__L1A0001015594-MSS2_24label.png is 1
# TRAIN GF2_PMS2__L1A0001723989-MSS2_24label.png is 2
# TRAIN GF2_PMS1__L1A0001765570-MSS1_24label.png is 3
# TRAIN GF2_PMS2__L1A0001708261-MSS2_24label.png is 4
# TRAIN GF2_PMS2__L1A0001642620-MSS2_24label.png is 5
# TEST GF2_PMS2__L1A0001367840-MSS2_24label.png is 6
# TEST GF2_PMS1__L1A0001064454-MSS1_24label.png is 7
# TRAIN GF2_PMS2__L1A0001799009-MSS2_24label.png is 8
# TRAIN GF2_PMS2__L1A0001206072-MSS2_24label.png is 9
# TRAIN GF2_PMS1__L1A0001680853-MSS1_24label.png is 10
# TRAIN GF2_PMS1__L1A0001491417-MSS1_24label.png is 11
# TRAIN GF2_PMS1__L1A0001217916-MSS1_24label.png is 12
# TRAIN GF2_PMS2__L1A0001876775-MSS2_24label.png is 13
# TRAIN GF2_PMS2__L1A0001116443-MSS2_24label.png is 14
# TRAIN GF2_PMS2__L1A0001723991-MSS2_24label.png is 15
# TRAIN GF2_PMS2__L1A0001566654-MSS2_24label.png is 16
# TEST GF2_PMS2__L1A0001416129-MSS2_24label.png is 17
# ...

# %%
test_images_names_list = [    
    "GF2_PMS1__L1A0001064454-MSS1",
    "GF2_PMS1__L1A0001118839-MSS1",
    "GF2_PMS1__L1A0001344822-MSS1",
    "GF2_PMS1__L1A0001348919-MSS1",
    "GF2_PMS1__L1A0001366278-MSS1",
    "GF2_PMS1__L1A0001366284-MSS1",
    "GF2_PMS1__L1A0001395956-MSS1",
    "GF2_PMS1__L1A0001432972-MSS1",
    "GF2_PMS1__L1A0001670888-MSS1",
    "GF2_PMS1__L1A0001680857-MSS1",
    "GF2_PMS1__L1A0001680858-MSS1",
    "GF2_PMS1__L1A0001757429-MSS1",
    "GF2_PMS1__L1A0001765574-MSS1",
    "GF2_PMS2__L1A0000607677-MSS2",
    "GF2_PMS2__L1A0000607681-MSS2",
    "GF2_PMS2__L1A0000718813-MSS2",
    "GF2_PMS2__L1A0001038935-MSS2",
    "GF2_PMS2__L1A0001038936-MSS2",
    "GF2_PMS2__L1A0001119060-MSS2",
    "GF2_PMS2__L1A0001367840-MSS2",
    "GF2_PMS2__L1A0001378491-MSS2",
    "GF2_PMS2__L1A0001378501-MSS2",
    "GF2_PMS2__L1A0001396036-MSS2",
    "GF2_PMS2__L1A0001396037-MSS2",
    "GF2_PMS2__L1A0001416129-MSS2",
    "GF2_PMS2__L1A0001471436-MSS2",
    "GF2_PMS2__L1A0001517494-MSS2",
    "GF2_PMS2__L1A0001591676-MSS2",
    "GF2_PMS2__L1A0001787564-MSS2",
    "GF2_PMS2__L1A0001821754-MSS2"
    ]

# %%
import os
hyper_images_source = "/home/pablo.canosa/wip/datasets/gaofen/Image_16bit_BGRNir/"


hyper_train_dest = "/home/pablo.canosa/wip/datasets/split_gaofen/train_16bit/"
hyper_test_dest = "/home/pablo.canosa/wip/datasets/split_gaofen/test_16bit/"

for image_idx, image_filename in enumerate(os.listdir(hyper_images_source)):
    #This is used to check if the test images are in train
    #delete the file of extension od image_filename
    image_filename_cmp = image_filename.split(".")[0]
    if image_filename_cmp not in test_images_names_list:
        print(f"TRAIN {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + hyper_images_source + image_filename + " " + hyper_train_dest)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
    else:
        print(f"TEST {image_filename} is {image_idx}")
        #Copy the image to destiny_path_image
        os.system("cp " + hyper_images_source + image_filename + " " + hyper_test_dest)
        #print("cp " + images_dir + "/" + image_filename + " " + destiny_path_image)
# Out:
# TEST GF2_PMS2__L1A0001367840-MSS2.tiff is 0
# TEST GF2_PMS1__L1A0001395956-MSS1.tiff is 1
# TEST GF2_PMS1__L1A0001118839-MSS1.tiff is 2
# TEST GF2_PMS2__L1A0001821754-MSS2.tiff is 3
# TRAIN GF2_PMS2__L1A0000958144-MSS2.tiff is 4
# TRAIN GF2_PMS2__L1A0001246645-MSS2.tiff is 5
# TEST GF2_PMS2__L1A0001378491-MSS2.tiff is 6
# TRAIN GF2_PMS2__L1A0001757320-MSS2.tiff is 7
# TRAIN GF2_PMS1__L1A0001335463-MSS1.tiff is 8
# TRAIN GF2_PMS2__L1A0001787577-MSS2.tiff is 9
# TRAIN GF2_PMS1__L1A0001064469-MSS1.tiff is 10
# TRAIN GF2_PMS2__L1A0001757484-MSS2.tiff is 11
# TRAIN GF2_PMS2__L1A0001723989-MSS2.tiff is 12
# TRAIN GF2_PMS1__L1A0001910522-MSS1.tiff is 13
# TRAIN GF2_PMS2__L1A0001035795-MSS2.tiff is 14
# TRAIN GF2_PMS2__L1A0001757317-MSS2.tiff is 15
# TRAIN GF2_PMS2__L1A0001251800-MSS2.tiff is 16
# TRAIN GF2_PMS1__L1A0001668483-MSS1.tiff is 17
# TRAIN GF2_PMS2__L1A0000564692-MSS2.tiff is 18
# TRAIN GF2_PMS2__L1A0001015597-MSS2.tiff is 19
# TRAIN GF2_PMS2__L1A0001573999-MSS2.tiff is 20
# ...
